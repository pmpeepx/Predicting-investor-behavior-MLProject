# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"D:\datasets\investors.csv")
data = data.rename(columns={'Which best describes your gender?':'gender'})
data = data.drop(columns=['Username', 'Timestamp'])
data.head(2)
# Out:
#   gender  Age occupation      education Investment proportion  rank  rank.1  \
# 0   Male   39   Salaried  Post Graduate        Yes  10% - 20%     3       3
# 1   Male   30   Salaried  Post Graduate        Yes  20% - 30%     3       6
#
#    rank.2  rank.3  ...  monitor_investment  expect_return  Preferred_avenue  \
# 0       3       3  ...             Monthly      10% - 20%    Fixed Deposits
# 1       2       2  ...              Weekly      10% - 20%            Equity
#
#   Savings_objective         Reason_equity       Reason_MF  \
# 0   Retirement Plan  Power of compounding  Better Returns
# 1   Retirement Plan  Capital Appreciation  Better Returns
#
#        purpose_investment          Reason_gb      Reason_fd  \
# 0  Savings for retirement    Safe Investment  Fixed returns
# 1         Wealth creation  Risk-free returns  Fixed returns
#
#                      source
# 0  Newspapers and Magazines
# 1                  Internet
#
# [2 rows x 27 columns]

# %%
 data.describe()
# Out:
#               Age        rank      rank.1      rank.2      rank.3      rank.4  \
# count  132.000000  132.000000  132.000000  132.000000  132.000000  132.000000
# mean    32.992424    4.795455    4.537879    3.416667    4.090909    4.113636
# std     10.924792    1.860553    1.775169    1.548413    1.758098    1.839547
# min     18.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%     25.750000    4.000000    3.000000    2.000000    3.000000    3.000000
# 50%     30.000000    5.000000    5.000000    4.000000    4.000000    4.000000
# 75%     37.250000    7.000000    6.000000    4.000000    5.000000    6.000000
# max     70.000000    7.000000    7.000000    7.000000    7.000000    7.000000
#
#            rank.5      rank.6
# count  132.000000  132.000000
# mean     4.772727    4.492424
# std      1.859947    1.696409
# min      1.000000    1.000000
# 25%      4.000000    3.000000
# 50%      5.000000    5.000000
# 75%      6.250000    6.000000
# max      7.000000    7.000000

# %%
data.isna().sum()
# Out:
# gender                  0
# Age                     0
# occupation              0
# education               0
# Investment              0
# proportion              0
# rank                    0
# rank.1                  0
# rank.2                  0
# rank.3                  0
# rank.4                  0
# rank.5                  0
# rank.6                  0
# stock_invest            0
# factors                 0
# Investment_objective    0
# investment_time         0
# monitor_investment      0
# expect_return           0
# Preferred_avenue        0
# Savings_objective       0
# Reason_equity           0
# Reason_MF               0
# purpose_investment      0
# Reason_gb               0
# Reason_fd               0
# source                  0
# dtype: int64

# %%
x = data[['Age', 'gender', 'education', 'occupation','rank.1','rank.2','rank.3','rank.4','rank.5','rank.6', 'proportion', ]]
y = data['Investment']

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
column = make_column_transformer(
    (OneHotEncoder(), ['occupation', 'education', 'gender', 'proportion']),
    remainder='passthrough'
)

# %%
x = column.fit_transform(x)

# %%
x = np.asanyarray(x)
y = np.asanyarray(y)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %%
model_params = { 
    'DecisionTreeClassifier': {
       'model': DecisionTreeClassifier(),
       'params': {'max_depth': [6, 8, 10],
                  'min_samples_split':[2, 4, 8],
                  'min_samples_leaf': [2, 4, 8]}
},
'RandomForestClassifier': {
    'model': RandomForestClassifier(),
    'params': {'n_estimators':[100, 125, 150],
               'max_depth':[8, 10, 12]}
},
'MLPClassifier':{
    'model': MLPClassifier(),
    'params': {'hidden_layer_sizes':[16, 64, 80, 100],
               'max_iter':[50, 100, 125]}
},
'SVC':{
    'model': SVC(),
    'params':{'kernel':['sigmoid', 'linear', 'rbf'],
              'C': [1, 10, 20]}
}
}

# %%
from sklearn.model_selection import GridSearchCV
scores = []
for model_name, mp in model_params.items():
    test = GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    test.fit(x, y)
    scores.append({
        'model': model_name,
        'best_score': test.best_score_,
        'best_params': test.best_params_
    })
# Out:
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
dataframe = pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])
dataframe
# Out:
#                     model  best_score  \
# 0  DecisionTreeClassifier    0.727350
# 1  RandomForestClassifier    0.787749
# 2           MLPClassifier    0.803419
# 3                     SVC    0.780342
#
#                                          best_params
# 0  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...
# 1             {'max_depth': 12, 'n_estimators': 150}
# 2        {'hidden_layer_sizes': 64, 'max_iter': 125}
# 3                          {'C': 1, 'kernel': 'rbf'}

# %%
model = MLPClassifier(hidden_layer_sizes=64, max_iter=125)
model.fit(x_train, y_train)
# Out:
# c:\Users\ZAITOON.iR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (125) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=64, max_iter=125)

# %%
model.score(x_train, y_train)
# Out:
# 0.8952380952380953

# %%
model.score(x_test, y_test)
# Out:
# 0.8518518518518519

# %%
x_train = pd.DataFrame(x_train)
x_new = x_train.sample(2, random_state=99)

# %%
y_pred_new = model.predict(x_new)
y_pred_new
# Out:
# array(['Yes', 'Yes'], dtype='<U3')
